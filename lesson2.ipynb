# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data_points.csv")

# %%
df.head()
# Out:
#     applicantName salutation gender                    email  mobile_numbers  \
# 0        John Doe        Mr.      M        johndoe@gmail.com    256701234567
# 1      Mary Akena        Ms.      F      maryakena@gmail.com    256712345678
# 2  Samuel Katumba        Mr.      M  samuelkatumba@gmail.com    256723456789
# 3    Grace Nakato        Ms.      F    gracenakato@gmail.com    256734567890
# 4    Peter Okello        Mr.      M    peterokello@gmail.com    256745678901
#
#   maritalStatus     religion date_of_birth         disability nationality  \
# 0        Single    Christian    1990-01-15  Visual Impairment     Ugandan
# 1       Married       Muslim    1985-03-22               none     Ugandan
# 2        Single    Christian    1992-07-30               none     Ugandan
# 3       Married  Traditional    1988-11-05               none     Ugandan
# 4      Divorced    Christian    1995-06-18               none     Ugandan
#
# ...

# %%
df.head(10)
# Out:
#        applicantName salutation gender                       email  \
# 0           John Doe        Mr.      M           johndoe@gmail.com
# 1         Mary Akena        Ms.      F         maryakena@gmail.com
# 2     Samuel Katumba        Mr.      M     samuelkatumba@gmail.com
# 3       Grace Nakato        Ms.      F       gracenakato@gmail.com
# 4       Peter Okello        Mr.      M       peterokello@gmail.com
# 5       Anna Babirye        Ms.      F       annababirye@gmail.com
# 6         James Kato        Mr.      M         jameskato@gmail.com
# 7        Sarah Laker        Ms.      F        sarahlaker@gmail.com
# 8  Josephine Nakaayi        Ms.      F  josephinenakaayi@gmail.com
# 9       Andrew Obote        Mr.      M       andrewobote@gmail.com
#
#    mobile_numbers maritalStatus     religion date_of_birth         disability  \
# 0    256701234567        Single    Christian    1990-01-15  Visual Impairment
# ...

# %%
df.columns
# Out:
# Index(['applicantName', 'salutation', 'gender', 'email', 'mobile_numbers',
#        'maritalStatus', 'religion', 'date_of_birth', 'disability',
#        'nationality', 'districtOfOrigin', 'districtOfBirth',
#        'placeOfResidence', 'nationalIdNo', 'addressVillage',
#        'addressSubCounty', 'addressDistrict'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   applicantName     100 non-null    object
#  1   salutation        100 non-null    object
#  2   gender            100 non-null    object
#  3   email             100 non-null    object
#  4   mobile_numbers    100 non-null    int64
#  5   maritalStatus     100 non-null    object
#  6   religion          100 non-null    object
#  7   date_of_birth     100 non-null    object
#  8   disability        100 non-null    object
#  9   nationality       100 non-null    object
#  10  districtOfOrigin  100 non-null    object
#  11  districtOfBirth   100 non-null    object
#  12  placeOfResidence  100 non-null    object
#  13  nationalIdNo      100 non-null    object
#  14  addressVillage    100 non-null    object
#  15  addressSubCounty  100 non-null    object
# ...

# %%
df.describe()
# Out:
#        mobile_numbers
# count    1.000000e+02
# mean     2.565668e+11
# std      2.566603e+08
# min      2.561001e+11
# 25%      2.563482e+11
# 50%      2.565951e+11
# 75%      2.567729e+11
# max      2.569901e+11

# %%
names = df["applicantName"]

# %%
names
# Out:
# 0           John Doe
# 1         Mary Akena
# 2     Samuel Katumba
# 3       Grace Nakato
# 4       Peter Okello
#            ...
# 95     Victor Mubiru
# 96    Norah Nakabugo
# 97     Denis Bwanika
# 98     Gloria Mukisa
# 99      Fred Kalungi
# Name: applicantName, Length: 100, dtype: object

# %%
df.columns
# Out:
# Index(['applicantName', 'salutation', 'gender', 'email', 'mobile_numbers',
#        'maritalStatus', 'religion', 'date_of_birth', 'disability',
#        'nationality', 'districtOfOrigin', 'districtOfBirth',
#        'placeOfResidence', 'nationalIdNo', 'addressVillage',
#        'addressSubCounty', 'addressDistrict'],
#       dtype='object')

# %%
df[["applicantName", "districtOfBirth"]]
# Out:
#      applicantName districtOfBirth
# 0         John Doe         Kampala
# 1       Mary Akena            Gulu
# 2   Samuel Katumba            Arua
# 3     Grace Nakato         Mbarara
# 4     Peter Okello            Lira
# ..             ...             ...
# 95   Victor Mubiru           Moshi
# 96  Norah Nakabugo          Dodoma
# 97   Denis Bwanika          Kitgum
# 98   Gloria Mukisa     Kaberamaido
# 99    Fred Kalungi         Kayunga
#
# [100 rows x 2 columns]

# %%
df["addressDistrict"].unique()
# Out:
# array(['Kampala', 'Jinja', 'Entebbe', 'Mbarara', 'Gulu', 'Fort Portal',
#        'Arua', 'Lira', 'Mbale', 'Soroti', 'Hoima', 'Kasese', 'Masaka',
#        'Iganga', 'Kabale', 'Tororo', 'Mityana', 'Wakiso', 'Mukono',
#        'Mpigi', 'Luwero', 'Kamuli', 'Pallisa', 'Bushenyi', 'Ntungamo',
#        'Rukungiri', 'Nakasongola', 'Kaberamaido', 'Apac', 'Bugiri',
#        'Nebbi', 'Kitgum', 'Moroto', 'Kapchorwa', 'Kalangala', 'Amuru',
#        'Kisoro', 'Adjumani', 'Masindi', 'Buliisa', 'Kiboga', 'Rakai',
#        'Lyantonde', 'Sembabule', 'Kyotera', 'Kyenjojo', 'Kibale',
#        'Kaliro', 'Buvuma', 'Bukomansimbi', 'Butambala', 'Buhweju',
#        'Kibaale', 'Manafwa', 'Ntoroko', 'Rubirizi', 'Namayingo',
#        'Amolatar', 'Kyegegwa', 'Nakaseke', 'Kayunga', 'Buyende', 'Budaka',
#        'Bududa', 'Bulambuli', 'Kween', 'Bukedea', 'Lamwo', 'Dokolo',
#        'Nwoya', 'Otuke', 'Amuria', 'Katakwi', 'Sironko', 'Alebtong',
# ...

# %%
df["addressDistrict"].value_counts()
# Out:
# addressDistrict
# Tororo     2
# Kampala    1
# Bududa     1
# Katakwi    1
# Amuria     1
#           ..
# Kitgum     1
# Nebbi      1
# Bugiri     1
# Apac       1
# Ngora      1
# Name: count, Length: 99, dtype: int64

# %%
df.isnull().sum()
# Out:
# applicantName       0
# salutation          0
# gender              0
# email               0
# mobile_numbers      0
# maritalStatus       0
# religion            0
# date_of_birth       0
# disability          0
# nationality         0
# districtOfOrigin    0
# districtOfBirth     0
# placeOfResidence    0
# nationalIdNo        0
# addressVillage      0
# addressSubCounty    0
# addressDistrict     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["addressVillage"].hist(bins=20)
# Out:
# <Axes: >

# %%
plt.scatter(df["districtOfBirth"], df["districtOfOrigin"])
plt.xlabel("Disability")
plt.ylabel("districtOfOrigin")
plt.title("A scatter graph")
plt.show()

# %%
plt.scatter(df["districtOfBirth"], df["districtOfOrigin"])
plt.xlabel("Disability")
plt.ylabel("districtOfOrigin")
plt.title("A scatter graph")
plt.show()
