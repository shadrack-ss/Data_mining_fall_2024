# %%
#create a dataframe for your project

# %%
import pandas as pd

# %%
data_point = {
  "applicantName": [
    "John Doe", "Mary Akena", "Samuel Katumba", "Grace Nakato", "Peter Okello", 
    "Anna Babirye", "James Kato", "Sarah Laker", "Josephine Nakaayi", "Andrew Obote", 
    "Catherine Alupo", "Michael Kintu", "Esther Amoding", "David Mukasa", "Irene Kyomugisha", 
    "Emmanuel Odoi", "Beatrice Nantongo", "Paul Lumumba", "Fiona Atim", "Simon Byaruhanga", 
    "Nancy Abbo", "Joseph Lukwago", "Brenda Nandutu", "Charles Ssemanda", "Emily Namuli", 
    "Ronald Kaggwa", "Patricia Namutebi", "Alex Mugisha", "Florence Bukenya", "Henry Musoke", 
    "Dorah Tendo", "Martin Kakuru", "Betty Akello", "Frank Tumusiime", "Phiona Mirembe", 
    "Brian Kizito", "Agnes Nalubega", "Steven Ocen", "Lydia Nankunda", "Daniel Kirunda", 
    "Ruth Ayebare", "Patrick Kamoga", "Gladys Mwaka", "Derrick Otim", "Olive Nanziri", 
    "Geoffrey Nsubuga", "Doreen Apio", "Elijah Kiyimba", "Mildred Namaganda", "Wilberforce Muwonge", 
    "Susan Lule", "Moses Kiiza", "Vivian Kemigisha", "Anthony Adong", "Rachael Aine", 
    "George Kabugo", "Hellen Nakyejwe", "Denis Tumwine", "Juliet Akullu", "Allan Kagimu", 
    "Harriet Nabaasa", "Richard Mugabi", "Priscilla Akumu", "Kenneth Ojara", "Monica Namono", 
    "Ivan Kabanda", "Shadia Namukasa", "Christopher Mutyaba", "Judith Ayoo", "Francis Okumu", 
    "Miriam Nampijja", "Nicholas Bwambale", "Grace Namusoke", "Patrick Nsubuga", "Gloria Ayo", 
    "Robert Kanyike", "Winnie Kabahuma", "Lawrence Odong", "Charity Ndagire", "Innocent Kirya", 
    "Fatuma Nalwanga", "Jackson Mbabazi", "Margret Okumu", "Emmanuel Bukenya", "Christine Awor", 
    "Stephen Nyeko", "Sharon Nabwire", "Samuel Kagwa", "Rebecca Nalwoga", "Wilson Katende", 
    "Janet Katushabe", "Amos Oryema", "Diana Namara", "Ibrahim Mutebi", "Sylvia Nabiryo", 
    "Victor Mubiru", "Norah Nakabugo", "Denis Bwanika", "Gloria Mukisa", "Fred Kalungi",
  ],
  
  
  "salutation": [
    "Mr.","Ms.", "Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Ms.","Mr.",
    "Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.",
    "Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.",
    "Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.",
    "Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.",
    "Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.",
    "Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.",
    "Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.",
    "Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.",
    "Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr.","Ms.","Mr."
  ],
  
  "gender": [
    "M", "F", "M", "F", "M", "F", "M", "F", "F", "M",
    "F", "M", "F", "M", "F", "M", "F", "M", "F", "M",
    "F", "M", "F", "M", "F", "M", "F", "M", "F", "M",
    "F", "M", "F", "M", "F", "M", "F", "M", "F", "M",
    "F", "M", "F", "M", "F", "M", "F", "M", "F", "M",
    "F", "M", "F", "M", "F", "M", "F", "M", "F", "M",
    "F", "M", "F", "M", "F", "M", "F", "M", "F", "M",
    "F", "M", "F", "M", "F", "M", "F", "M", "F", "M",
    "F", "M", "F", "M", "F", "M", "F", "M", "F", "M",
    "F", "M", "F", "M", "F", "M", "F", "M", "F", "M"
  ],

  "email": [
    "johndoe@gmail.com", "maryakena@gmail.com", "samuelkatumba@gmail.com", "gracenakato@gmail.com",
    "peterokello@gmail.com", "annababirye@gmail.com", "jameskato@gmail.com", "sarahlaker@gmail.com",
    "josephinenakaayi@gmail.com", "andrewobote@gmail.com", "catherinealupo@gmail.com", "michaelkintu@gmail.com",
    "estheramoding@gmail.com", "davidmukasa@gmail.com", "irenekyomugisha@gmail.com", "emmanuelodoi@gmail.com",
    "beatricenantongo@gmail.com", "paullumumba@gmail.com", "fionaatim@gmail.com", "simonbyaruhanga@gmail.com",
    "nancyabbo@gmail.com", "josephlukwago@gmail.com", "brendanandutu@gmail.com", "charlesssemanda@gmail.com",
    "emilynamuli@gmail.com", "ronaldkaggwa@gmail.com", "patricianamutebi@gmail.com", "alexmugisha@gmail.com",
    "florencebukenya@gmail.com", "henrymusoke@gmail.com", "dorah tendo@gmail.com", "martinkakuru@gmail.com",
    "bettyakello@gmail.com", "franktumusiime@gmail.com", "phionamirembe@gmail.com", "briankizito@gmail.com",
    "agnesnalubega@gmail.com", "stevenocen@gmail.com", "lydianankunda@gmail.com", "danielkirunda@gmail.com",
    "ruthayebare@gmail.com", "patrickkamoga@gmail.com", "gladysmwaka@gmail.com", "derrickotim@gmail.com",
    "olivenanziri@gmail.com", "geoffreynsubuga@gmail.com", "doreenapio@gmail.com", "elijahkiyimba@gmail.com",
    "mildrednamaganda@gmail.com", "wilberforcemuwonge@gmail.com", "susanlule@gmail.com", "moseskiiza@gmail.com",
    "viviankemigisha@gmail.com", "anthonyadong@gmail.com", "rachaelaine@gmail.com", "georgekabugo@gmail.com",
    "hellennakyejwe@gmail.com", "denistumwine@gmail.com", "julietakullu@gmail.com", "allankagimu@gmail.com",
    "harrietnabaasa@gmail.com", "richardmugabi@gmail.com", "priscillaakumu@gmail.com", "kennethojara@gmail.com",
    "monicanamono@gmail.com", "ivankabanda@gmail.com", "shadianamukasa@gmail.com", "christophermutyaba@gmail.com",
    "judithayoo@gmail.com", "francisokumu@gmail.com", "miriamnampijja@gmail.com", "nicholasbwambale@gmail.com",
    "gracenamusoke@gmail.com", "patricknsubuga@gmail.com", "gloriaayo@gmail.com", "robertkanyike@gmail.com",
    "winniekabahuma@gmail.com", "lawrenceodong@gmail.com", "charityndagire@gmail.com", "innocentkirya@gmail.com",
    "fatumanalwanga@gmail.com", "jacksonmbabazi@gmail.com", "margretokumu@gmail.com", "emmanuelbukenya@gmail.com",
    "christineawor@gmail.com", "stephennyeko@gmail.com", "sharonnabwire@gmail.com", "samuelkagwa@gmail.com",
    "rebeccanabwoga@gmail.com", "wilsonkatende@gmail.com", "janetkatushabe@gmail.com", "amosoryema@gmail.com",
    "diananamara@gmail.com", "ibrahimmutebi@gmail.com", "sylvianabiryo@gmail.com", "victormubiru@gmail.com",
    "norahnakabugo@gmail.com", "denisbwanika@gmail.com", "gloriamukisa@gmail.com", "fredkalungi@gmail.com"
  ],

"mobile_numbers": [
    +256701234567, +256712345678, +256723456789, +256734567890, +256745678901, +256756789012,
    +256767890123, +256778901234, +256789012345, +256790123456, +256801234567, +256812345678,
    +256823456789, +256834567890, +256845678901, +256856789012, +256867890123, +256878901234, 
    +256889012345, +256890123456, +256901234567, +256912345678, +256923456789, +256934567890, 
    +256945678901, +256956789012, +256967890123, +256978901234, +256989012345, +256990123456, 
    +256100123456, +256110234567, +256120345678, +256130456789, +256140567890, +256150678901,
    +256160789012, +256170890123, +256180901234, +256190012345, +256200123456, +256210234567, 
    +256220345678, +256230456789, +256240567890, +256250678901, +256260789012, +256270890123,
    +256280901234, +256290012345, +256300123456, +256310234567, +256320345678, +256330456789, 
    +256340567890, +256350678901, +256360789012, +256370890123, +256380901234, +256390012345,
    +256400123456, +256410234567, +256420345678, +256430456789, +256440567890, +256450678901, 
    +256460789012, +256470890123, +256480901234, +256490012345, +256500123456, +256510234567,
    +256520345678, +256530456789, +256540567890, +256550678901, +256560789012, +256570890123, 
    +256580901234, +256590012345, +256600123456, +256610234567, +256620345678, +256630456789,
    +256640567890, +256650678901, +256660789012, +256670890123, +256680901234, +256690012345, 
    +256700123456, +256710234567, +256720345678, +256730456789, +256740567890, +256750678901,
    +256760789012, +256770890123, +256780901234, +256790012345
],


  "maritalStatus": [
    "Single", "Married", "Single", "Married", "Divorced", 
    "Single", "Married", "Divorced", "Single", "Married", 
    "Single", "Married", "Divorced", "Single", "Married", 
    "Single", "Married", "Divorced", "Single", "Married", 
    "Single", "Divorced", "Married", "Single", "Married", 
    "Single", "Married", "Divorced", "Single", "Married", 
    "Single", "Married", "Divorced", "Single", "Married", 
    "Single", "Married", "Single", "Divorced", "Married", 
    "Single", "Married", "Single", "Divorced", "Single", 
    "Married", "Single", "Married", "Divorced", "Single", 
    "Married", "Divorced", "Single", "Married", "Single", 
    "Married", "Divorced", "Single", "Married", "Single", 
    "Divorced", "Single", "Married", "Single", "Married", 
    "Divorced", "Single", "Married", "Single", "Married", 
    "Divorced", "Single", "Married", "Divorced", "Single", 
    "Married", "Single", "Married", "Divorced", "Single", 
    "Married", "Single", "Married", "Single", "Divorced", 
    "Single", "Married", "Divorced", "Single", "Married", 
    "Single", "Divorced", "Married", "Single", "Married", 
    "Single", "Divorced", "Married", "Single", "Married"
  ],
  
  "religion": [
    "Christian", "Muslim", "Christian", "Traditional", "Christian", 
    "Muslim", "Christian", "Traditional", "Christian", "Muslim", 
    "Christian", "Traditional", "Christian", "Muslim", "Christian", 
    "Traditional", "Christian", "Muslim", "Christian", "Traditional", 
    "Christian", "Muslim", "Christian", "Traditional", "Christian", 
    "Muslim", "Christian", "Traditional", "Christian", "Muslim", 
    "Christian", "Traditional", "Christian", "Muslim", "Christian", 
    "Traditional", "Christian", "Muslim", "Christian", "Traditional", 
    "Christian", "Muslim", "Christian", "Traditional", "Christian", 
    "Muslim", "Christian", "Traditional", "Christian", "Muslim", 
    "Christian", "Traditional", "Christian", "Muslim", "Christian", 
    "Traditional", "Christian", "Muslim", "Christian", "Traditional", 
    "Christian", "Muslim", "Christian", "Traditional", "Christian", 
    "Muslim", "Christian", "Traditional", "Christian", "Muslim", 
    "Christian", "Traditional", "Christian", "Muslim", "Christian", 
    "Traditional", "Christian", "Muslim", "Christian", "Traditional", 
    "Christian", "Muslim", "Christian", "Traditional", "Christian", 
    "Muslim", "Christian", "Traditional", "Christian", "Muslim", 
    "Christian", "Traditional", "Christian", "Muslim", "Christian",
    "Christian", "Muslim", "Christian", "Traditional", "Christian"
  ],


  "date_of_birth": [
    "1990-01-15", "1985-03-22", "1992-07-30", "1988-11-05", "1995-06-18", "1980-02-14",
    "1993-09-27", "1987-12-01", "1991-04-20", "1986-08-11", "1994-05-09", "1989-10-30",
    "1996-03-03", "1983-07-25", "1990-12-12", "1982-01-28", "1995-08-19", "1984-06-07",
    "1991-11-23", "1987-02-16", "1993-04-15", "1986-09-29", "1990-10-05", "1981-05-14",
    "1992-12-30", "1985-03-18", "1994-07-22", "1988-11-11", "1991-06-09", "1980-02-25",
    "1996-01-04", "1989-08-17", "1993-10-21", "1987-12-14", "1995-05-06", "1983-09-12",
    "1990-03-30", "1984-11-19", "1992-08-01", "1986-02-22", "1991-07-15", "1988-10-28",
    "1994-04-09", "1982-12-05", "1990-01-19", "1985-06-30", "1993-09-14", "1987-03-21",
    "1996-11-11", "1981-05-27", "1992-02-18", "1989-07-09", "1994-12-24", "1986-08-30",
    "1990-03-15", "1984-10-02", "1991-01-26", "1983-05-11", "1995-09-19", "1988-06-14",
    "1993-11-07", "1980-04-22", "1996-08-05", "1987-12-18", "1992-02-09", "1985-03-12",
    "1994-07-27", "1989-10-15", "1991-06-21", "1986-01-30", "1990-09-04", "1983-11-29",
    "1995-05-17", "1988-02-14", "1992-12-08", "1981-08-23", "1993-04-11", "1987-10-30",
    "1996-01-19", "1984-06-05", "1990-03-22", "1989-09-15", "1994-12-02", "1986-07-18",
    "1991-05-29", "1982-11-10", "1995-08-25", "1988-01-14", "1993-06-30", "1987-04-17",
    "1992-10-09", "1980-02-20", "1996-07-12", "1983-12-01", "1990-05-15", "1985-03-28",
    "1994-09-19", "1989-11-14", "1991-06-03", "1986-01-22"
    ],
  
  
  "disability": [
    "Visual Impairment", "none", "none", "none", "none", "none", "none", "none",
      "Chronic Pain", "none", "none", "none", "none", "none",
      "Mental Health Disorders", "none", "none", "none", "none", "none", 
      "none", "none", "none", "none", "none", "none", "none", "none",
      "none", "none", "none", "none", "none", "none", "none", "none",
      "none", "none", "none", "none", "none", "none", "none", "none",
      "none", "none", "none", "Hearing Impairment", "none", "none", "none", "none",
      "none", "none", "none", "none", "none", "none", "none", "none",
      "none", "none", "none", "none", "none", "none", "none", "none",
      "none", "none", "none", "none", "none", "Mobility Impairment", "none", "none",
      "Cognitiv Disability", "none", "none", "none", "none", "none", "none", "none",
      "none", "none", "none", "none", "none", "none", "none", "none",
      "none", "none", "none", "none", "none", "none", "Speech Impairment", "none"
  ],
  
  
  "nationality": [
    "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan",
    "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan",
    "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan",
    "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan",
    "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan",
    "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan",
    "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan", "Ugandan",
    "Greek", "Portuguese", "Swiss", "Ugandan", "Ugandan", "Hungarian",
    "Romanian", "Bulgarian", "Slovak", "Croatian", "Serbian", "Slovenian",
    "Ukrainian", "Lithuanian", "Latvian", "Colombiana", "Icelandic", "Maltese",
    "New Zealander", "Bulgarian", "Ugangan", "Tongan", "Papua New Guinean", "Kenyan",
    "Malaysian", "Ugandan", "Bruneian", "Cambodian", "Uganda", "Burmese",
    "Afghan", "Lebanese", "Bulgaria", "Serbian", "American","Sierra Leonean"
    "Israeli", "Palestinian", "Jordanian", "Lebanese", "Syrian", "Iraqi",
    "Haitian", "Dominican", "Costa Rican", "Panamanian", "Guatemalan", "Mongolian","ugandan",
    "Bulgarian", "Sri Lankan", "Lebanese", "Afro-American","Ugandan", "Kenyan",
    "Tanzanian", "Ugandan", "Ugandan", "Ugandan"
  ],
  
  "districtOfOrigin": [  "Kampala", "Gulu", "Arua", "Mbarara", "Lira", "Jinja",
    "Mbale", "Masaka", "Fort Portal", "Hoima", "Soroti", "Tororo",
    "Kitgum", "Moroto", "Bushenyi", "Kabarole", "Kasese", "Iganga",
    "Luwero", "Mukono", "Wakiso", "Nakapiripirit", "Mityana", "Mayuge",
    "Oyam", "Adjumani", "Kagadi", "Kalangala", "Kiboga", "Kyegegwa",
    "Mpigi", "Butambala", "Rakai", "Kyankwanzi", "Buliisa", "Kumi",
    "Attica", "Lisbon", "Geneva", "Szeged", "Bucharest", "Sofia",
    "Bratislava", "Zagreb", "Belgrade", "Ljubljana", "Kiev", "Vilnius",
    "Riga", "Bogotá", "Reykjavik", "Valletta", "Auckland", "Plovdiv",
    "Tongatapu", "Port Moresby", "Nairobi", "Kuala Lumpur", "Bandar Seri Begawan", "Phnom Penh",
    "Yangon", "Kabul", "Beirut", "Belgrade", "New York", "Freetown",
    "Tel Aviv", "Ramallah", "Amman", "Damascus", "Baghdad", "Port-au-Prince",
    "Santo Domingo", "San José", "Panama City", "Guatemala City", "Ulaanbaatar", "Nabul",
    "Varna", "Colombo", "Tripoli", "Brooklyn", "Nakuru", "Moshi",
    "Dodoma", "Kitgum", "Kaberamaido", "Kayunga", "Apac", "Alebtong",
    "Masindi", "Kaliro", "Isingiro", "Kiruhura", "Kamwenge", "Bukomansimbi",
    "Kalungu", "Lyantonde", "Rubanda", "Sheema"
  ],
  
  "districtOfBirth": [
    "Kampala", "Gulu", "Arua", "Mbarara", "Lira", "Jinja",
    "Mbale", "Masaka", "Fort Portal", "Hoima", "Soroti", "Tororo",
    "Luwero", "Mukono", "Wakiso", "Nakapiripirit", "Mityana", "Mayuge",
    "Kitgum", "Moroto", "Bushenyi", "Kabarole", "Kasese", "Iganga",
    "Kabale", "Rukungiri", "Pallisa", "Katakwi", "Kamuli", "Ntungamo",
    "Luwero", "Mukono", "Wakiso", "Nakapiripirit", "Mityana", "Mayuge",
    "Oyam", "Adjumani", "Kagadi", "Kalangala", "Kiboga", "Kyegegwa",
    "Mpigi", "Butambala", "Rakai", "Kyankwanzi", "Buliisa", "Kumi",
    "Attica", "Lisbon", "Geneva", "Szeged", "Bucharest", "Sofia",
    "Bratislava", "Zagreb", "Belgrade", "Ljubljana", "Kiev", "Vilnius",
    "Riga", "Bogotá", "Reykjavik", "Valletta", "Auckland", "Plovdiv",
    "Tongatapu", "Port Moresby", "Nairobi", "Kuala Lumpur", "Bandar Seri Begawan", "Phnom Penh",
    "Yangon", "Kabul", "Beirut", "Belgrade", "New York", "Freetown",
    "Tel Aviv", "Ramallah", "Amman", "Damascus", "Baghdad", "Port-au-Prince",
    "Santo Domingo", "San José", "Panama City", "Guatemala City", "Ulaanbaatar", "Nabul",
    "Varna", "Colombo", "Tripoli", "Brooklyn", "Nakuru", "Moshi",
    "Dodoma", "Kitgum", "Kaberamaido", "Kayunga"
  ],  
  
  "placeOfResidence": [
    "Kampala", "Jinja", "Entebbe", "Mbarara", "Gulu", "Fort Portal",
    "Arua", "Lira", "Mbale", "Soroti", "Hoima", "Kasese",
    "Masaka", "Iganga", "Kabale", "Tororo", "Mityana", "Wakiso",
    "Mukono", "Mpigi", "Luwero", "Kamuli", "Pallisa", "Bushenyi",
    "Ntungamo", "Rukungiri", "Nakasongola", "Kaberamaido", "Apac", "Bugiri",
    "Nebbi", "Kitgum", "Moroto", "Kapchorwa", "Kalangala", "Amuru",
    "Kisoro", "Adjumani", "Masindi", "Buliisa", "Kiboga", "Rakai",
    "Lyantonde", "Sembabule", "Kyotera", "Kyenjojo", "Kibale", "Kaliro",
    "Buvuma", "Bukomansimbi", "Butambala", "Buhweju", "Kibaale", "Manafwa",
    "Ntoroko", "Rubirizi", "Namayingo", "Buliisa", "Amolatar", "Kyegegwa",
    "Nakaseke", "Kayunga", "Buyende", "Budaka", "Bududa", "Bulambuli",
    "Kween", "Bukedea", "Lamwo", "Dokolo", "Nwoya", "Otuke",
    "Amuria", "Katakwi", "Sironko", "Alebtong", "Bukwa", "Kisoro",
    "Kabong", "Zombo", "Kagadi", "Sheema", "Ibanda", "Kazo",
    "Kiruhura", "Isingiro", "Rubanda", "Kumi", "Kotido", "Agago",
    "Obongi", "Pakwach", "Madi-Okollo", "Omoro", "Butaleja", "Tororo",
    "Busia", "Mubende", "Kalungu", "Maracha"
  ],
  
  "nationalIdNo": [
    "CM7901234567UG", "CM8902345678UG", "CF9903456789UG", "CM1904567890UG", "CF2905678901UG", "CM3906789012UG",
    "CF4907890123UG", "CM5908901234UG", "CF6949012345UG", "CM7900123456UG", "CF8901234567UG", "CM9902345678UG",
    "CF0903456789UG", "CM1909667890UG", "CF2905678902UG", "CM3906779013UG", "CF4907890124UG", "CM5908901235UG",
    "CF6909012346UG", "CM7900123457UG", "CF8901234568UG", "CM9902345679UG", "CF0903456689UG", "CM1904567891UG",
    "CF2905678903UG", "CM3906789014UG", "CF4907890125UG", "CM5955901236UG", "CF6909012347UG", "CM7900123458UG",
    "CF8901239567UG", "CM9902345680UG", "CF0903456790UG", "CM1904367891UG", "CF2905678904UG", "CM3906723015UG",
    "CF4907890126UG", "CM5908901237UG", "CF6909012326UG", "CM7900123459UG", "CF8901234569UG", "CM9902345681UG",
    "CF0903456791UG", "CM1904567892UG", "CF2905678905UG", "CM3906789016UG", "CF4907890127UG", "CM5908901238UG",
    "CF6909012348UG", "CM7900123460UG", "CF8901234570UG", "CM9905345679UG", "CF0903459989UG", "CM1904567893UG",
    "CF2905678906UG", "CM3906789017UG", "CF4907890763UG", "CM5908901239UG", "CF6909012349UG", "CM7900123461UG",
    "CF8901234571UG", "CM9902345682UG", "CF0903456792UG", "CM1904567871UG", "CF2905678907UG", "CM3906789018UG",
    "CF4307890128UG", "CM5908901240UG", "CF6909012350UG", "CM7900123462UG", "CF8901234572UG", "CM9902345683UG",
    "CF0903456793UG", "CM1906367891UG", "CF2905678908UG", "CM3906789019UG", "CF4907890129UG", "CM5908901241UG",
    "CF6909012351UG", "CM7900123463UG", "CF8901234573UG", "CM9902345684UG", "CF0903456794UG", "CM1904547891UG",
    "CF2905678909UG", "CM3906789020UG", "CF4905780123UG", "CM5908901242UG", "CF6909012352UG", "CM7900123464UG",
    "CF8901234574UG", "CM9902345685UG", "CF0903456795UG", "CM1904567894UG", "CF2905678910UG", "CM3906789021UG",
    "CF0903456889UG", "CM1904567920UG", "CF2905678651UG", "CM3906789087UG"
  ],
  
  "addressVillage": [
    "Kibuye", "Bweyogerere", "Kitintale", "Nyamityobora", "Pece", "Kasusu",
    "Kuluva", "Adekokwok", "Namatala", "Kichinjaji", "Kiryatete", "Kisinga",
    "Kijjabwemi", "Bugumba", "Kirigime", "Nyangole", "Kigalama", "Nakawuka",
    "Namanve", "Kiringente", "Zirobwe", "Butansi", "Kamuge", "Nyakabirizi",
    "Ruhaama", "Bikurungu", "Wabinyonyi", "Obolokome", "Atik", "Nabukalu",
    "Pakwach", "Lamit", "Lotome", "Kwoti", "Lulindi", "Pabbo",
    "Nyakabande", "Pakelle", "Kinyara", "Bugoigo", "Kyakabadiima", "Byakabanda",
    "Nabigasa", "Mijwala", "Buyamba", "Nyantungo", "Kasambya", "Bugulumbya",
    "Busamuzi", "Butenga", "Bulo", "Bihanga", "Kikwaya", "Bunabwana",
    "Kisenyi", "Katanda", "Hamatuba", "Biso", "Bujubuli", "Kasangombe",
    "Lugasa", "Namaseke", "Bukamba", "Naboa", "Simu", "Bulegeni",
    "Kaptum", "Arabet", "Padibe", "Batta", "Purongo", "Otuke Town",
    "Wera", "Ngariam", "Budadiri", "Akura", "Chepsikunya", "Nyabwishenya",
    "Kacheri", "Nyapea", "Nyamacumu", "Masha", "Rwengiri", "Katunguru",
    "Kabura", "Nyakitunda", "Hamurwa", "Kobwin", "Kanawat", "Lamogi",
    "Obongi Town", "Panyimur", "Alikua", "Bobbi", "Busaba", "Sere",
    "Majanji", "Kasambya", "Lwamata", "Kawango"
  ],
  
  "addressSubCounty": [
    "Makindye", "Kira", "Nakawa", "Kamukuzi", "Pece", "West Division",
    "Ayivu", "Adekokwok", "Northern Division", "Eastern Division", "Hoima Central", "Bukonzo",
    "Kimanya", "Iganga Central", "Northern Division", "Tororo Municipality", "Busimbi", "Wakiso Town Council",
    "Mukono Central", "Kiringente", "Luwero Subcounty", "Butansi", "Kamuge", "Igara West",
    "Rubaare", "Buyanja", "Nakasongola", "Obolokome", "Atik", "Bugiri Central",
    "Panyango", "Kitgum Matidi", "Rupa", "Kwoti", "Kalangala Town", "Amuru Subcounty",
    "Nyakabande", "Pakele", "Masindi Town", "Buliisa Subcounty", "Kyakabadiima", "Byakabanda",
    "Nabigasa", "Mijwala", "Buyamba", "Nyantungo", "Kasambya Subcounty", "Bugulumbya",
    "Busamuzi", "Bukomansimbi", "Bulo", "Bihanga", "Kikwaya", "Bunambutye",
    "Kisenyi", "Katanda", "Hamatuba", "Biso", "Bujubuli", "Kasangombe",
    "Lugasa", "Ntenjeru", "Bukamba", "Budaka Town Council", "Simu", "Bulegeni",
    "Kaproron", "Arabet", "Padibe", "Batta", "Purongo", "Otuke Subcounty",
    "Wera", "Ngariam", "Budadiri", "Akura", "Kaptum", "Nyabwishenya",
    "Kacheri", "Nyapea", "Muhoro", "Kazo Subcounty", "Rwengiri", "Katunguru",
    "Nyamarwa", "Kabuyanda", "Hamurwa", "Kobwin", "Kotido Subcounty", "Lamogi",
    "Obongi Town Council", "Panyimur", "Alikua", "Odek", "Busaba", "Butaleja Town Council",
    "Majanji", "Kasambya", "Lwamata", "Mubende Subcounty"
  ],
  
  
  "addressDistrict": [
    "Kampala", "Jinja", "Entebbe", "Mbarara", "Gulu", "Fort Portal",
    "Arua", "Lira", "Mbale", "Soroti", "Hoima", "Kasese",
    "Masaka", "Iganga", "Kabale", "Tororo", "Mityana", "Wakiso",
    "Mukono", "Mpigi", "Luwero", "Kamuli", "Pallisa", "Bushenyi",
    "Ntungamo", "Rukungiri", "Nakasongola", "Kaberamaido", "Apac", "Bugiri",
    "Nebbi", "Kitgum", "Moroto", "Kapchorwa", "Kalangala", "Amuru",
    "Kisoro", "Adjumani", "Masindi", "Buliisa", "Kiboga", "Rakai",
    "Lyantonde", "Sembabule", "Kyotera", "Kyenjojo", "Kibale", "Kaliro",
    "Buvuma", "Bukomansimbi", "Butambala", "Buhweju", "Kibaale", "Manafwa",
    "Ntoroko", "Rubirizi", "Namayingo", "Amolatar", "Kyegegwa", "Nakaseke",
    "Kayunga", "Buyende", "Budaka", "Bududa", "Bulambuli", "Kween",
    "Bukedea", "Lamwo", "Dokolo", "Nwoya", "Otuke", "Amuria",
    "Katakwi", "Sironko", "Alebtong", "Bukwa", "Kabong", "Zombo",
    "Kagadi", "Sheema", "Ibanda", "Kazo", "Kiruhura", "Isingiro",
    "Rubanda", "Kumi", "Kotido", "Agago", "Obongi", "Pakwach",
    "Madi-Okollo", "Omoro", "Butaleja", "Tororo", "Busia", "Mubende",
    "Kalungu", "Maracha", "Kibuku", "Ngora"
  ]
}

df = pd.DataFrame(data_point)
df.to_csv('data_points.csv', index=False)
